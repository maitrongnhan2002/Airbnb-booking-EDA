# %% [markdown]
# ![NYC Skyline](nyc.jpg)
#
# Welcome to New York City, one of the most-visited cities in the world. There are many Airbnb listings in New York City to meet the high demand for temporary lodging for travelers, which can be anywhere between a few nights to many months. In this project, we will take a closer look at the New York Airbnb market by combining data from multiple file types like `.csv`, `.tsv`, and `.xlsx`.
#
# Recall that **CSV**, **TSV**, and **Excel** files are three common formats for storing data.
# Three files containing data on 2019 Airbnb listings are available to you:
#
# **data/airbnb_price.csv**
# This is a CSV file containing data on Airbnb listing prices and locations.
# - **`listing_id`**: unique identifier of listing
# - **`price`**: nightly listing price in USD
# - **`nbhood_full`**: name of borough and neighborhood where listing is located
#
# **data/airbnb_room_type.xlsx**
# This is an Excel file containing data on Airbnb listing descriptions and room types.
# - **`listing_id`**: unique identifier of listing
# - **`description`**: listing description
# - **`room_type`**: Airbnb has three types of rooms: shared rooms, private rooms, and entire homes/apartments
#
# **data/airbnb_last_review.tsv**
# This is a TSV file containing data on Airbnb host names and review dates.
# - **`listing_id`**: unique identifier of listing
# - **`host_name`**: name of listing host
# - **`last_review`**: date when the listing was last reviewed

# %% [markdown]
# **Import Price DB**

# %%
# Import necessary packages
import pandas as pd
import numpy as np

# Begin coding here ...
# Use as many cells as you like
df_price = pd.read_csv('data/airbnb_price.csv')
print(df_price.head())
print(df_price.info())
# Out:
#    listing_id        price                nbhood_full
# 0        2595  225 dollars         Manhattan, Midtown
# 1        3831   89 dollars     Brooklyn, Clinton Hill
# 2        5099  200 dollars     Manhattan, Murray Hill
# 3        5178   79 dollars  Manhattan, Hell's Kitchen
# 4        5238  150 dollars       Manhattan, Chinatown
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25209 entries, 0 to 25208
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   listing_id   25209 non-null  int64
#  1   price        25209 non-null  object
#  2   nbhood_full  25209 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 591.0+ KB
# None

# %% [markdown]
# **Import Room DB**

# %%
df_room = pd.read_excel('data/airbnb_room_type.xlsx')
print(df_room.head())
print(df_room.info())
# Out:
#    listing_id                                description        room_type
# 0        2595                      Skylit Midtown Castle  Entire home/apt
# 1        3831            Cozy Entire Floor of Brownstone  Entire home/apt
# 2        5099  Large Cozy 1 BR Apartment In Midtown East  Entire home/apt
# 3        5178            Large Furnished Room Near B'way     private room
# 4        5238         Cute & Cozy Lower East Side 1 bdrm  Entire home/apt
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25209 entries, 0 to 25208
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   listing_id   25209 non-null  int64
#  1   description  25199 non-null  object
#  2   room_type    25209 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 591.0+ KB
# None

# %% [markdown]
# **Import Review DB**

# %%
df_review = pd.read_csv('data/airbnb_last_review.tsv', sep = '\t')
print(df_review.head())
print(df_review.info())
# Out:
#    listing_id    host_name   last_review
# 0        2595     Jennifer   May 21 2019
# 1        3831  LisaRoxanne  July 05 2019
# 2        5099        Chris  June 22 2019
# 3        5178     Shunichi  June 24 2019
# 4        5238          Ben  June 09 2019
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25209 entries, 0 to 25208
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   listing_id   25209 non-null  int64
#  1   host_name    25201 non-null  object
#  2   last_review  25209 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 591.0+ KB
# None

# %% [markdown]
# **Merging the DFs**

# %%
df_full = pd.merge(df_room, df_price, on = "listing_id", how = "left")
df_full = pd.merge(df_full, df_review, on = "listing_id", how = "left")
print(df_full.head())
print(df_full.info())
# Out:
#    listing_id  ...   last_review
# 0        2595  ...   May 21 2019
# 1        3831  ...  July 05 2019
# 2        5099  ...  June 22 2019
# 3        5178  ...  June 24 2019
# 4        5238  ...  June 09 2019
#
# [5 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25209 entries, 0 to 25208
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   listing_id   25209 non-null  int64
#  1   description  25199 non-null  object
#  2   room_type    25209 non-null  object
#  3   price        25209 non-null  object
#  4   nbhood_full  25209 non-null  object
#  5   host_name    25201 non-null  object
#  6   last_review  25209 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.5+ MB
# None

# %% [markdown]
# **Convert last_review to Datetime, and price to Int**

# %%
df_full["last_review"] = pd.to_datetime(df_full["last_review"], format = "%B %d %Y")
df_full["price"] = df_full["price"].str.replace(" dollars", "", regex=False).astype(int)
print(df_full["price"])
print(df_full.info())
# Out:
# 0        225
# 1         89
# 2        200
# 3         79
# 4        150
#         ...
# 25204    129
# 25205     45
# 25206    235
# 25207    100
# 25208     30
# Name: price, Length: 25209, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25209 entries, 0 to 25208
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   listing_id   25209 non-null  int64
#  1   description  25199 non-null  object
#  2   room_type    25209 non-null  object
#  3   price        25209 non-null  int64
#  4   nbhood_full  25209 non-null  object
#  5   host_name    25201 non-null  object
#  6   last_review  25209 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(4)
# memory usage: 1.5+ MB
# None

# %% [markdown]
# **What are the dates of the earliest and most recent reviews?**

# %%
min_review_date = df_full["last_review"].min()
max_review_date = df_full["last_review"].max()
print(min_review_date)
print(max_review_date)
# Out:
# 2019-01-01 00:00:00
# 2019-07-09 00:00:00

# %% [markdown]
# **How many of the listings are private rooms?**

# %%
print(df_full["room_type"].unique())
df_full["room_type"] = df_full["room_type"].str.lower()
private_count = df_full["room_type"].value_counts()["private room"]
print(private_count)
# Out:
# ['Entire home/apt' 'private room' 'Private room' 'entire home/apt'
#  'PRIVATE ROOM' 'shared room' 'ENTIRE HOME/APT' 'Shared room'
#  'SHARED ROOM']
# 11356

# %% [markdown]
# **What is the average listing price?**

# %%
avg_price = df_full["price"].mean().round(2)
print(avg_price)
# Out:
# 141.78

# %% [markdown]
# **Combine the new variables into one DataFrame called review_dates**

# %%
combined = {
    "first_reviewed": min_review_date,
    "last_reviewed": max_review_date,
    "nb_private_rooms": private_count,
    "avg_price": avg_price
}

review_dates = pd.DataFrame([combined])
print(review_dates)
# Out:
#   first_reviewed last_reviewed  nb_private_rooms  avg_price
# 0     2019-01-01    2019-07-09             11356     141.78
